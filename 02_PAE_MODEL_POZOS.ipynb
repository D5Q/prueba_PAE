# %% [markdown]
# <a href="https://colab.research.google.com/github/D5Q/prueba_PAE/blob/master/02_PAE_MODEL_POZOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
corriente_bomba_falla = np.load('/content/drive/My Drive/corriente_bomba_falla.npy')
corriente_bomba_ok = np.load('/content/drive/My Drive/corriente_bomba_ok.npy')

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(corriente_bomba_falla)
plt.show()
plt.plot(corriente_bomba_ok)

# %%
X_train = corriente_bomba_ok[15000:]
X_val = corriente_bomba_ok[:15000]
y_train = corriente_bomba_ok[15001:]
